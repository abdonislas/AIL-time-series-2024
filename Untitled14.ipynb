# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import yfinance as yf
from statsmodels.tsa.seasonal import STL

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['lines.linewidth'] = 1.5
dark_style = {
    'figure.facecolor': '#212946',
    'axes.facecolor': '#212946',
    'savefig.facecolor':'#212946',
    'axes.grid': True,
    'axes.grid.which': 'both',
    'axes.spines.left': False,
    'axes.spines.right': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False,
    'grid.color': '#2A3459',
    'grid.linewidth': '1',
    'text.color': '0.9',
    'axes.labelcolor': '0.9',
    'xtick.color': '0.9',
    'ytick.color': '0.9',
    'font.size': 12 }
plt.rcParams.update(dark_style)

from pylab import rcParams
rcParams['figure.figsize'] = (18,7)

# %%
stock = "NVDA"
ticker = yf.Ticker(stock)
df = ticker.history(start = "2020-01-01", end = "2023-12-31", interval = "1mo")["Close"]
df = df.reset_index() # Reset index to make 'Date' a column
df["unique_id"]="1"
df.columns=["ds", "y", "unique_id"]
df.head()
# Out:
#                          ds         y unique_id
# 0 2020-01-01 00:00:00-05:00  5.886479         1
# 1 2020-02-01 00:00:00-05:00  6.724028         1
# 2 2020-03-01 00:00:00-05:00  6.566866         1
# 3 2020-04-01 00:00:00-04:00  7.281349         1
# 4 2020-05-01 00:00:00-04:00  8.844342         1

# %%
print(df.dtypes)
# Out:
# ds           datetime64[ns, America/New_York]
# y                                     float64
# unique_id                              object
# dtype: object

# %%
df["ds"] = pd.to_datetime(df["ds"])

# %%
# !pip install statsforecast

# %%
StatsForecast.plot(df, engine="matplotlib")

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)


max_lags = len(df) // 2 - 1


lags = min(60, max_lags)

plot_acf(df["y"], lags=lags, ax=axs[0], color="fuchsia")
axs[0].set_title("Autocorrelation")

plot_pacf(df["y"], lags=lags, ax=axs[1], color="lime")
axs[1].set_title("Partial Autocorrelation")

plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
a = seasonal_decompose(df["y"], model = "add", period=12)
a.plot();

# %%
Y_train_df = df[df.ds <= '2022-08-01']
Y_test_df = df[df.ds > '2022-08-01']

# %%
Y_train_df.shape, Y_test_df.shape
# Out:
# ((32, 3), (16, 3))

# %%
sns.lineplot(Y_train_df,x="ds", y="y", label="Train")
sns.lineplot(Y_test_df, x="ds", y="y", label="Test")
plt.show()

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA
from statsforecast.arima import arima_string

# %%
# Setting up the model
season_length = 12  # Monthly data seasonality
horizon = len(Y_test_df)  # number of predictions

# Configuring StatsForecast
sf = StatsForecast(models=[AutoARIMA(season_length=season_length)], freq='MS', n_jobs=1)

# Debugging step: Check columns and structure of Y_train_df
print("Columns in Y_train_df:", Y_train_df.columns)
print("Head of Y_train_df:\n", Y_train_df.head())

# Fitting the model
sf.fit(Y_train_df.set_index("ds")[["y"]])

# Making predictions
forecast = sf.predict(h=horizon)
print(forecast)
# Out:
# Columns in Y_train_df: Index(['ds', 'y', 'unique_id'], dtype='object')
# Head of Y_train_df:
#                           ds         y unique_id
# 0 2020-01-01 00:00:00-05:00  5.886479         1
# 1 2020-02-01 00:00:00-05:00  6.724028         1
# 2 2020-03-01 00:00:00-05:00  6.566866         1
# 3 2020-04-01 00:00:00-04:00  7.281349         1
# 4 2020-05-01 00:00:00-04:00  8.844342         1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
print(df['ds'].min(), df['ds'].max())
# Out:
# 2020-01-01 00:00:00-05:00 2023-12-01 00:00:00-05:00

# %%
# Fitting the model
sf.fit(Y_train_df.set_index("ds")[["y"]])

# Making predictions
forecast = sf.predict(h=horizon)
print(forecast)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-2e9897b1d8b6> in <cell line: 2>()
#       1 # Fitting the model
# ----> 2 sf.fit(Y_train_df.set_index("ds")[["y"]])
# ...

# %%
sf.fit(Y_train_df.set_index("ds")[["y"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-9037e830a4ab> in <cell line: 1>()
# ----> 1 sf.fit(Y_train_df.set_index("ds")[["y"]])
#       2
#
# ...

# %%
StatsForecast(models=[AutoARIMA])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a02a4857d85e> in <cell line: 1>()
# ----> 1 StatsForecast(models=[AutoARIMA])
#
# TypeError: _StatsForecast.__init__() missing 1 required positional argument: 'freq'

# %%
forecast=pd.Series(pd.date_range("2014-01-01", freq="ys", periods=6))
forecast=pd.DataFrame(forecast)
forecast.columns=["ds"]
forecast["hat"]=y_hat_dict.get("mean")
forecast["unique_id"]="1"
forecast
# Out:
# <ipython-input-18-6d1b8ef58e97>:1: FutureWarning: 'ys' is deprecated and will be removed in a future version, please use 'YS' instead.
#   forecast=pd.Series(pd.date_range("2014-01-01", freq="ys", periods=6))
#           ds        hat unique_id
# 0 2014-01-01  49.506748         1
# 1 2015-01-01  49.506748         1
# 2 2016-01-01  49.506748         1
# 3 2017-01-01  49.506748         1
# 4 2018-01-01  49.506748         1
# 5 2019-01-01  49.506748         1

# %%
sns.lineplot(train,x="ds", y="y", label="Train")
sns.lineplot(test, x="ds", y="y", label="Test")
sns.lineplot(forecast,x="ds", y="hat", label="Forecast",)
plt.show()
